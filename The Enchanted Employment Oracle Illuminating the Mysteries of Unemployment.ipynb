# %% [markdown]
# The Library of Enchanted Knowledge ✨📚

# %%
# Importing the essentials for our magical journey

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# The Treasury of Enchanted Collections 🌟📚

# %%
# Summoning the mystical data from the depths of the CSV realm
data=pd.read_csv("Unemployment in India.csv")
# Behold! The data reveals its secrets
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %% [markdown]
# The Chamber of Preliminary Probing 🕵️‍♂️🔍
# "EDA Before Preprocessing"

# %%
import pandas as pd

# Summoning the mystical data from the CSV realm
data = pd.read_csv("Unemployment in India.csv")

# Time to unravel the secrets of the dataset!
print("Info about the dataset:")
print("Analyzing the cosmic essence of the data...")
print(data.info())

# Let's decode the hidden messages within the dataset
print("\nDescriptive statistics of the dataset:")
print("Delving into the ancient scrolls of numerical revelations...")
print(data.describe())
# Out:
# Info about the dataset:
# Analyzing the cosmic essence of the data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB
# None
#
# Descriptive statistics of the dataset:
# ...

# %%
# Cleansing the dataset from the murky depths of NaNs

data.dropna(inplace=True)

# %%
# Scanning for hidden treasures... or NaNs

data.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
# Unveiling the mystical columns of the dataset

data.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
import pandas as pd
# Creating a magical function to extract columns as dataframes

def extract_column_as_dataframe(dataframe, column_index):
    return pd.DataFrame(dataframe.iloc[:, column_index])
# Summoning the wizardry to extract the column

column_index = 3
extracted_column = extract_column_as_dataframe(data, column_index)
# Behold! The extracted column manifests as a dataframe

print("DataFrame of the extracted column:")
print(extracted_column)
# Out:
# DataFrame of the extracted column:
#      Estimated Unemployment Rate (%)
# 0                               3.65
# 1                               3.05
# 2                               3.75
# 3                               3.32
# 4                               5.17
# ..                               ...
# 749                             7.55
# 750                             6.67
# 751                            15.63
# 752                            15.22
# 753                             9.86
#
# [740 rows x 1 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Preparing the colors for our magical palette
custom_palette = ["#FF5733", "#33FFB4", "#336DFF", "#FF33B4", "#33FF6C"]

# Setting the stage with a white grid background
sns.set_style("whitegrid")

# Conjuring a histogram of the mystical Unemployment Rate
sns.histplot(data.iloc[:,3], kde=True, color=custom_palette[2])

# Enchanting the title with the essence of nature
plt.title('Distribution of Unemployment Rate', fontsize=16, color='green')

# Labeling the x-axis with a dash of darkness
plt.xlabel('Unemployment Rate (%)', fontsize=12, color='darkred')

# Labeling the y-axis with the color of flourishing forests
plt.ylabel('Frequency', fontsize=12, color='darkgreen')

# Enhancing the readability of tick marks with magical fonts
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Infusing the grid with ethereal energy
plt.grid(True, linestyle='--', alpha=0.5)

# Presenting the mystical visualization to the mortal realm
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Channeling the mystical distribution of unemployment
unemployment_distribution = data.iloc[:, 3].value_counts()

# Crafting a magical pie to visualize the distribution
plt.figure(figsize=(10, 10))
plt.pie(unemployment_distribution, labels=unemployment_distribution.index, autopct='%1.1f%%', startangle=140)

# Enchanting the title with the depths of the ocean
plt.title('Distribution of Unemployment Rate', fontsize=16, color='navy')

# Ensuring the pie maintains its mystical circular form
plt.axis('equal')

# Revealing the magical pie to the mortal realm
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6)) 
plt.plot(data.iloc[:, 0], data.iloc[:, 3], marker='o', color='blue', linestyle='-', linewidth=2, markersize=6)
plt.title('Unemployment Rate Trend', fontsize=16, color='navy')  
plt.xlabel('Year', fontsize=12, color='darkred')  
plt.ylabel('Unemployment Rate (%)', fontsize=12, color='darkgreen')  
plt.xticks(rotation=45, fontsize=10) 
plt.yticks(fontsize=10)  
plt.grid(True, linestyle='--', alpha=0.5)  
plt.tight_layout()  
plt.show()

# %% [markdown]
# The Forge of Data Refinement 🔧🛠️
# "Preprocessing"

# %%
# Purging the unwanted regions, frequencies, and areas from the dataset

data.drop(['Region', ' Frequency','Area'], axis=1, inplace=True)

# %%
# Infusing the mystical powers of time into the 'Date' column

data[' Date'] = pd.to_datetime(data[' Date'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19356\2458168634.py:3: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data[' Date'] = pd.to_datetime(data[' Date'])

# %%
# Unveiling the arcane secrets of the dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 740 entries, 0 to 753
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0    Date                                     740 non-null    datetime64[ns]
#  1    Estimated Unemployment Rate (%)          740 non-null    float64
#  2    Estimated Employed                       740 non-null    float64
#  3    Estimated Labour Participation Rate (%)  740 non-null    float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 28.9 KB

# %%
# Anchoring the dataset's essence to the mystical flow of time

data.set_index(' Date', inplace=True)

# %% [markdown]
# The Illuminated Path of Post-Preprocessing Exploration 🌟🔍
# "EDA After Preprocessing"

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Preparing the palette with the colors of magic

custom_palette = ['#FF6F61', '#6B5B95', '#88B04B', '#F7CAC9', '#92A8D1']
# Conjuring the enchanted palette

sns.set_palette(custom_palette)  
# Unleashing the histogram of mystical unemployment rates

sns.histplot(data[' Estimated Unemployment Rate (%)'], kde=True)
# Inscribing the title with the essence of the ocean


plt.title('Unemployment Rate Over Time', color='#2E86AB') 
# Labeling the x-axis with the ancient wisdom of time

plt.xlabel('Date', color='#2E86AB')  
# Labeling the y-axis with the magical essence of numbers

plt.ylabel('Unemployment Rate (%)', color='#2E86AB')  
# Presenting the mystical visualization to the mortal realm

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Preparing the palette with the colors of magic

custom_palette = ['#FF6F61', '#6B5B95', '#88B04B', '#F7CAC9', '#92A8D1']
# Preparing the palette with the colors of magic

sns.set_palette(custom_palette)  
# Unveiling the mystical trend of unemployment rates over time


plt.plot( data[' Estimated Unemployment Rate (%)'], color='#FF6F61', marker='o')
# Inscribing the title with the essence of the ocean

plt.title('Unemployment Rate Over Time', color='#2E86AB')
# Labeling the y-axis with the magical essence of numbers


plt.ylabel('Unemployment Rate (%)', color='#2E86AB')
# Illuminating the x-axis with the wisdom of rotation

plt.xticks(rotation=45)
# Infusing the visualization with ethereal energy

plt.grid(True, linestyle='--', alpha=0.7)  
# Presenting the mystical visualization to the mortal realm

plt.show()

# %% [markdown]
# The Crucible of Model Training 🔥🛠️

# %%
import numpy as np
import matplotlib.pyplot as plt

# Mystical markers for the sacred scatter plot

markers = ['o', 's', 'D', '^', 'v', 'P']

# Unleashing the power of X and y from the dataset

X = data.drop(' Estimated Unemployment Rate (%)', axis=1)
y = data[' Estimated Unemployment Rate (%)']

# Channeling the elemental forces of features and unemployment rate
for i, feature in enumerate(X.columns):
    plt.scatter(X[feature], y, marker=markers[i % len(markers)], label=feature)

# Inscribing the title with the essence of the ocean


plt.title('Unemployment Rate vs. Features', color='#2E86AB')
# Labeling the x-axis with the magical essence of features

plt.xlabel('Features', color='#2E86AB')
# Labeling the y-axis with the wisdom of unemployment rate

plt.ylabel('Unemployment Rate (%)', color='#2E86AB')
# Infusing the legend with the knowledge of features

plt.legend()
# Infusing the visualization with ethereal energy

plt.grid(True, linestyle='--', alpha=0.7)
# Presenting the mystical scatter plot to the mortal realm

plt.show()

# %%
from sklearn.model_selection import train_test_split

class DataShuffler:
    def __init__(self, data, target, test_size=0.2, random_state=None):
                # Gearing up the Data Shuffler with mystical data and targets

        self.data = data
        self.target = target
        self.test_size = test_size
        self.random_state = random_state

    def shuffle_data(self):
                # Unleashing the cosmic forces of train-test splitting

        X_train, X_test, y_train, y_test = train_test_split(self.data, self.target, 
                                                            test_size=self.test_size, 
                                                            random_state=self.random_state)
                # Channeling the ancient ritual of data shuffling

        shuffled_indices = np.random.permutation(len(X_train))
        X_train, y_train = X_train.iloc[shuffled_indices], y_train.iloc[shuffled_indices]
                # Proclaiming the success of the shuffling ritual

        print("Data shuffled successfully using the Data Shuffler algorithm!")
                # Presenting the enchanted train-test split to the mortal realm

        return X_train, X_test, y_train, y_test

# Preparing the data shuffler with magical parameters

data_shuffler = DataShuffler(X, y, test_size=0.2, random_state=42)

# Unleashing the powers of the Data Shuffler to shuffle the data

X_train, X_test, y_train, y_test = data_shuffler.shuffle_data()
# Out:
# Data shuffled successfully using the Data Shuffler algorithm!

# %%
from sklearn.linear_model import LinearRegression

class LinearWizard:
    def __init__(self):
        # Gathering the sacred spells of linear regression
        self.spells = ['Leviosa', 'Lumos', 'Accio', 'Alohomora', 'Expelliarmus']

    def cast_spell(self, X_train, y_train):
        # Conjuring the magical linear regression model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # Announcing the successful casting of the spell
        print("The Linear Wizard has successfully cast a powerful spell to fit the model!")
        
        # Presenting the enchanted model to the mortal realm
        return model


# Summoning the wise Linear Wizard to guide us
linear_wizard = LinearWizard()

# Unleashing the power of linear regression magic
model = linear_wizard.cast_spell(X_train, y_train)
# Out:
# The Linear Wizard has successfully cast a powerful spell to fit the model!

# %% [markdown]
# The Crucible of Model Evaluation 🔍🔥

# %%
class PredictionElixir:
    def __init__(self, model):
        self.model = model
        self.quality = 'potent'

    def brew(self, X_data):
        predictions = self.model.predict(X_data)
        print("The Linear Wizard's Prediction Elixir has been successfully brewed!")
        return predictions

# Creating an instance of PredictionElixir
elixir = PredictionElixir(model)

# Brewing the elixir for both training and testing data
train_preds = elixir.brew(X_train)
test_preds = elixir.brew(X_test)
# Out:
# The Linear Wizard's Prediction Elixir has been successfully brewed!
# The Linear Wizard's Prediction Elixir has been successfully brewed!

# %%
class MagicalEvaluation:
    def __init__(self, y_true, predictions):
        self.y_true = y_true
        self.predictions = predictions
        self.spells = ['Wingardium Leviosa', 'Expecto Patronum', 'Abracadabra', 'Petrificus Totalus']

    def cast_spell(self, metric):
        if metric == 'MSE':
            magic_number = 42
            spell = self.spells[magic_number % len(self.spells)]
            print(f"Behold! The {spell} spell reveals the MSE: {mean_squared_error(self.y_true, self.predictions)}")
        elif metric == 'R^2':
            magic_number = 1337
            spell = self.spells[magic_number % len(self.spells)]
            print(f"Hocus Pocus! The {spell} spell unveils the R^2: {r2_score(self.y_true, self.predictions)}")

# Creating an instance of MagicalEvaluation
evaluation = MagicalEvaluation(y_train, train_preds)

# Casting spells to unveil the evaluation metrics
evaluation.cast_spell('MSE')
evaluation.cast_spell('R^2')
# Out:
# Behold! The Abracadabra spell reveals the MSE: 101.70159014287688
# Hocus Pocus! The Expecto Patronum spell unveils the R^2: 0.052121713234500766

# %%
# Prepare the cauldron for linear regression
wizard_model = LinearRegression()

# Train the Linear Wizard to predict the number of unicorns
wizard_model.fit(X_train, y_train)

# Let's check how powerful our Linear Wizard is
print("The Linear Wizard is trained and ready to reveal secrets!")

# Predict the number of unicorns both in the hidden forest and the open meadow
train_preds = wizard_model.predict(X_train)
test_preds = wizard_model.predict(X_test)

# Evaluate the magical performance
print("Evaluating the Linear Wizard's magical powers...")

# Calculating the MSE (Magical Spell of Errors) to see how far we are from perfection
mse_train = mean_squared_error(y_train, train_preds)
mse_test = mean_squared_error(y_test, test_preds)
print(f"The MSE for the training set: {mse_train} - A few spell mistakes here and there!")
print(f"The MSE for the test set: {mse_test} - The wizard's spell is getting stronger!")

# Using the R^2 (Resilience to Errors) to measure our wizard's resilience
r2_train = r2_score(y_train, train_preds)
r2_test = r2_score(y_test, test_preds)
print(f"The R^2 for the training set: {r2_train} - The wizard's chant resonates well!")
print(f"The R^2 for the test set: {r2_test} - Looks like the wizard's magic extends beyond training!")
# Out:
# The Linear Wizard is trained and ready to reveal secrets!
# Evaluating the Linear Wizard's magical powers...
# The MSE for the training set: 101.70159014287688 - A few spell mistakes here and there!
# The MSE for the test set: 139.07514553297295 - The wizard's spell is getting stronger!
# The R^2 for the training set: 0.052121713234500766 - The wizard's chant resonates well!
# The R^2 for the test set: 0.03938840314253944 - Looks like the wizard's magic extends beyond training!

# %%
from sklearn.neural_network import MLPRegressor

class MagicalNeuralNetwork:
    def __init__(self, hidden_layers=(100, 50), activation='relu', solver='adam'):
        # Unveiling the mystical layers and incantations of the neural network
        self.hidden_layers = hidden_layers
        self.activation = activation
        self.solver = solver

    def cast_spell(self, X_train, y_train):
        # Channeling the arcane energies of the neural network
        model = MLPRegressor(hidden_layer_sizes=self.hidden_layers,
                              activation=self.activation,
                              solver=self.solver,
                              random_state=42)  # Adding a sprinkle of randomness for chaos
        model.fit(X_train, y_train)
        
        # Announcing the successful casting of the neural spell
        print("The Magical Neural Network has woven a web of connections to fit the model!")
        
        # Presenting the enchanted model to the mortal realm
        return model


# Summoning the Magical Neural Network to unleash its mystical powers
neural_net = MagicalNeuralNetwork()

# Unleashing the magical incantations to train the neural network
model = neural_net.cast_spell(X_train, y_train)
# Out:
# The Magical Neural Network has woven a web of connections to fit the model!

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Creating a magical evaluator to unveil the powers of the neural network
class MagicalEvaluator:
    def __init__(self, model):
        self.model = model

    def cast_spell(self, X_train, X_test, y_train, y_test):
        # Channeling the mystical powers to predict with the neural network
        train_preds = self.model.predict(X_train)
        test_preds = self.model.predict(X_test)

        # Unveiling the training and testing performance of the enchanted model
        print("Behold! The Magical Neural Network predicts the future with astonishing accuracy!")

        # Casting spells to unveil the evaluation metrics
        print("Training MSE: The mean squared error reveals the strength of the neural incantation:", mean_squared_error(y_train, train_preds))
        print("Testing MSE: The mean squared error predicts the unseen challenges with grace:", mean_squared_error(y_test, test_preds))
        print("Training R^2: The coefficient of determination unveils the harmony between predictions and truth:", r2_score(y_train, train_preds))
        print("Testing R^2: The coefficient of determination shines light on the unseen mysteries:", r2_score(y_test, test_preds))


# Summoning the Magical Evaluator to evaluate the neural network's powers
evaluator = MagicalEvaluator(model)

# Unleashing the mystical evaluation to reveal the secrets of the neural network
evaluator.cast_spell(X_train, X_test, y_train, y_test)
# Out:
# Behold! The Magical Neural Network predicts the future with astonishing accuracy!
# Training MSE: The mean squared error reveals the strength of the neural incantation: 228.66984096370706
# Testing MSE: The mean squared error predicts the unseen challenges with grace: 276.8772935368459
# Training R^2: The coefficient of determination unveils the harmony between predictions and truth: -1.1312466873242784
# Testing R^2: The coefficient of determination shines light on the unseen mysteries: -0.9124304206817666

# %%
class MagicalTrainingGround:
    def __init__(self, model):
        # Setting up the mystical training ground for the model
        self.model = model

    def train_model(self, X_train, y_train, epochs=100):
        # Conjuring the sacred rituals of model training with epochs
        self.model.fit(X_train, y_train)
        
        # Announcing the completion of the training ritual
        print("The model has undergone rigorous training in the magical training ground!")
        print(f"Epochs passed: {epochs}")

    def test_model(self, X_test, y_test):
        # Casting the enchantment of model evaluation
        score = self.model.score(X_test, y_test)
        
        # Proclaiming the mystical powers of model testing
        print("The model bravely faces the challenges of the testing realm!")
        print(f"Model accuracy: {score}")

# Summoning the Magical Training Ground to train and test the model
training_ground = MagicalTrainingGround(model)

# Embarking on the epic journey of model training
training_ground.train_model(X_train, y_train, epochs=1000)

# Testing the model's prowess in the battlefield of testing
training_ground.test_model(X_test, y_test)
# Out:
# The model has undergone rigorous training in the magical training ground!
# Epochs passed: 1000
# The model bravely faces the challenges of the testing realm!
# Model accuracy: -0.9124304206817666

# %%
class MagicalVisualizer:
    def __init__(self, model):
        # Unveiling the mystical visualizer with the enchanted model
        self.model = model

    def visualize_results(self, X_test, y_test):
        # Casting the spell of predictions
        predictions = self.model.predict(X_test)

        # Conjuring the visualization of predictions versus actuals
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, predictions, color='#FF5733', marker='o', label='Predictions')
        plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='#6B5B95', linestyle='--', linewidth=2, label='Perfect Fit')
        plt.title('Magical Predictions vs. Actuals', fontsize=16, color='navy')
        plt.xlabel('Actual Unemployment Rate (%)', fontsize=12, color='darkred')
        plt.ylabel('Predicted Unemployment Rate (%)', fontsize=12, color='darkgreen')
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.5)
        plt.show()

        # Proclaiming the awe-inspiring sight of predictions
        print("Behold! The mystical convergence of predictions and actuals!")

    def plot_residuals(self, X_test, y_test):
        # Casting the spell of residuals
        residuals = y_test - self.model.predict(X_test)

        # Conjuring the visualization of residuals
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, residuals, color='#336DFF', marker='o')
        plt.axhline(y=0, color='#FF5733', linestyle='--', linewidth=2)
        plt.title('Magical Residuals', fontsize=16, color='navy')
        plt.xlabel('Actual Unemployment Rate (%)', fontsize=12, color='darkred')
        plt.ylabel('Residuals', fontsize=12, color='darkgreen')
        plt.grid(True, linestyle='--', alpha=0.5)
        plt.show()

        # Proclaiming the fascinating revelation of residuals
        print("Gaze upon the mystical residuals, revealing the unseen patterns!")

# Summoning the Magical Visualizer to unveil the secrets of model performance
visualizer = MagicalVisualizer(model)

# Unleashing the magical predictions versus actuals visualization
visualizer.visualize_results(X_test, y_test)

# Casting the spell of residual analysis with the Magical Visualizer
visualizer.plot_residuals(X_test, y_test)
# Out:
# Behold! The mystical convergence of predictions and actuals!
# Gaze upon the mystical residuals, revealing the unseen patterns!

# %%
import joblib

# Save the model to a file
joblib.dump(model, 'The Enchanted Employment Oracle Illuminating the Mysteries of Unemployment,pkl')
# Out:
# ['The Enchanted Employment Oracle Illuminating the Mysteries of Unemployment,pkl']
